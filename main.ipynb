# %% [markdown]
# # Introduction à la programmation objet avec Python LT

# %%
#import ComNum
import importlib
import numpy as np

# %%
import commNumStartLT; from commNumStartLT import Mesure
importlib.reload(commNumStartLT)
import commNumStartLT; from commNumStartLT import Modem
importlib.reload(commNumStartLT)
# Out:
# <module 'commNumStartLT' from 'c:\\Users\\energ\\Desktop\\Code\\Python\\TP_RT3R05\\commNumStartLT.py'>

# %% [markdown]
# ## Creation de l'objet et table de mapping

# %%
MyNemModem = Modem('PAM', 8, bits=np.random.binomial(1, 0.5, 12))
MyMapp = MyNemModem.mapping(7)
print(MyMapp)
# Out:
# [ 5.  3. -5. -1.]

# %%
signal = np.sin(np.linspace(0, 2 * np.pi, 100))  # Signal sinusoïdal

# Créer une instance de la classe Mesure
mesure = Mesure(signal)

# Assurez-vous que la méthode DSP est correctement implémentée
#MyMesure = mesure.DSP(fe=1000, type="Bi")  # Corriger "bi" par "Bi" (majuscule)
MyMesure2 = mesure.DSP(fe=100, type="mono", unit="Volts")
